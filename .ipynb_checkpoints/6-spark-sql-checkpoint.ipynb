# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("spark-sql").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/04/02 01:30:30 WARN Utils: Your hostname, LAPTOP-EC11ARA9, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/04/02 01:30:30 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/02 01:30:31 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
file_path = "data/sample_data_500_rows.csv"

# %%
df = spark.read.csv(file_path, header=True, inferSchema=True)

# %% [markdown]
# Register a view with name 'view1' and dataframe 'df'

# %%
df.createOrReplaceTempView("view1")

# %%
result = spark.sql("select gender, avg(salary) from view1 group by gender") #df

# %%
result.show()
# Out:
# +------+-----------------+
# |gender|      avg(salary)|
# +------+-----------------+
# |Female|81194.98701298701|
# | Other| 83354.6449704142|
# |  Male|86167.13559322034|
# +------+-----------------+

# %% [markdown]
# List all temp views registered

# %%
spark.catalog.listTables()
# Out:
# [Table(name='view1', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]

# %% [markdown]
# check if a view exists

# %%
spark.catalog.tableExists("view1")
# Out:
# True

# %%
# spark.catalog.dropTempView('view1') #returns False if view doesnt exist
